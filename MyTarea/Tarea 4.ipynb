# %% [markdown]
# ## Tarea 4

# %% [markdown]
# 1) regla del trapecio, velocidades.txt

# %%
import numpy as np

# %%
Velo = np.loadtxt("velocidades.txt", float)

# %%
Tiempo = []#Creo 2 listas vacías para separar los valores de tiempo y velocidades
Velocidad = [] 
for i in range(0,len(Velo)):
    Tiempo.append(Velo[i,0])  #el primer elemento de cada entrada de manchas es el tiempo, entonces lo agregamos a Tiempo
    Velocidad.append(Velo[i,1])

# %%
# Out:
# 101
